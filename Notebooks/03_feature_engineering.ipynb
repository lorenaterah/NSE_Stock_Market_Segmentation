# %% [markdown]
# # Feature Engineering
#
# Transform raw stock prices into risk features for clustering.

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../src')

from features import (
    calculate_returns,
    calculate_volatility_features,
    calculate_risk_metrics,
    calculate_technical_indicators,
    calculate_liquidity_features,
    calculate_momentum_features,
    calculate_drawdown,
    aggregate_stock_features
)

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('../Data/Processed/cleaned_nse.csv')
print(f"Loaded {len(df):,} rows for {df['Stock_code'].nunique()} stocks")

df.head(3)
# Out:
# Loaded 69,754 rows for 75 stocks
#          Date Stock_code                 Name  12m Low  12m High  Day Low  \
# 0  2021-01-04       ABSA  ABSA Bank Kenya Plc      8.5      14.2     9.42
# 1  2021-01-05       ABSA  ABSA Bank Kenya Plc      8.5      14.2     9.44
# 2  2021-01-06       ABSA  ABSA Bank Kenya Plc      8.5      14.2     9.40
#
#    Day High  Day Price  Previous  Change  %Change     Volume  Adjusted Price  \
# 0      9.80       9.52      9.66   -0.14     1.45    18500.0             0.0
# 1      9.70       9.44      9.52   -0.08     0.84  1923300.0             0.0
# 2      9.68       9.44      9.44    0.00     0.00   233400.0             0.0
#
#     Sector  Month  Year
# 0  Banking      1  2021
# 1  Banking      1  2021
# 2  Banking      1  2021

# %% [markdown]
# ## Step 1: Returns

# %%
df = df.groupby('Stock_code', group_keys=False).apply(calculate_returns)

print(f" Added: daily_return")
# Out:
#  Added: daily_return
# C:\Users\PC\AppData\Local\Temp\ipykernel_3200\624484591.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('Stock_code', group_keys=False).apply(calculate_returns)

# %% [markdown]
# ## Step 2: Volatility

# %%
df = df.groupby('Stock_code', group_keys=False).apply(calculate_volatility_features)
print(f"Added: volatility_5d, volatility_10d, volatility_20d")
# Out:
# Added: volatility_5d, volatility_10d, volatility_20d
# C:\Users\PC\AppData\Local\Temp\ipykernel_3200\1118812164.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('Stock_code', group_keys=False).apply(calculate_volatility_features)

# %% [markdown]
# ## Step 3: Risk Metrics

# %%
df = df.groupby('Stock_code', group_keys=False).apply(calculate_risk_metrics)
print(f"Added: downside_deviation_20d, var_95")
# Out:
# Added: downside_deviation_20d, var_95
# C:\Users\PC\AppData\Local\Temp\ipykernel_3200\3492156597.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('Stock_code', group_keys=False).apply(calculate_risk_metrics)

# %% [markdown]
# ## Step 4: Technical Indicators

# %%
df = df.groupby('Stock_code', group_keys=False).apply(calculate_technical_indicators)
print(f"Added: rsi, bb_width, macd")
# Out:
# Added: rsi, bb_width, macd
# C:\Users\PC\AppData\Local\Temp\ipykernel_3200\4127783887.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('Stock_code', group_keys=False).apply(calculate_technical_indicators)

# %% [markdown]
# ## Step 5: Liquidity

# %%
df = df.groupby('Stock_code', group_keys=False).apply(calculate_liquidity_features)
print(f"Added: avg_volume, volume_volatility, amihud_illiquidity")
# Out:
# Added: avg_volume, volume_volatility, amihud_illiquidity
# C:\Users\PC\AppData\Local\Temp\ipykernel_3200\1456975175.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('Stock_code', group_keys=False).apply(calculate_liquidity_features)

# %% [markdown]
# ## Step 6: Momentum

# %%
df = df.groupby('Stock_code', group_keys=False).apply(calculate_momentum_features)
print(f"Added: momentum_5d, momentum_20d, momentum_60d, ma_5, ma_20, ma_60")
# Out:
# Added: momentum_5d, momentum_20d, momentum_60d, ma_5, ma_20, ma_60
# C:\Users\PC\AppData\Local\Temp\ipykernel_3200\3232535510.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('Stock_code', group_keys=False).apply(calculate_momentum_features)

# %% [markdown]
# ## Step 7: Drawdown

# %%
df = df.groupby('Stock_code', group_keys=False).apply(calculate_drawdown)
print(f"Added: current_drawdown, max_drawdown")
# Out:
# Added: current_drawdown, max_drawdown
# C:\Users\PC\AppData\Local\Temp\ipykernel_3200\1112847196.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('Stock_code', group_keys=False).apply(calculate_drawdown)

# %% [markdown]
# ## Step 8: Aggregate to Stock Level

# %%
print("\nAggregating to stock level")
print(f"Before: {len(df):,} rows")

features_list = []
for stock_code, group in df.groupby('Stock_code'):
    stock_features = aggregate_stock_features(group)
    if stock_features is not None:
        features_list.append(stock_features)

df_features = pd.DataFrame(features_list)
print(f"After: {len(df_features)} stocks with {len(df_features.columns)} features")
df_features.head()
# Out:
# Aggregating to stock level
# Before: 69,754 rows
# After: 57 stocks with 26 features
#   Stock_code                    Sector                                Name  \
# 0       ABSA                   Banking                 ABSA Bank Kenya Plc
# 1       BAMB   Construction and Allied                  Bamburi Cement Ltd
# 2        BAT  Manufacturing and Allied  British American Tobacco Kenya Plc
# 3        BKG                   Banking                        BK Group Plc
# 4        BOC  Manufacturing and Allied                       BOC Kenya Plc
#
#    volatility_mean  volatility_max  volatility_5d  downside_deviation  \
# 0         0.012240        0.032507       0.010669            0.007478
# 1         0.023726        0.089329       0.021072            0.013241
# 2         0.011709        0.027272       0.010182            0.006908
# 3         0.028116        0.057793       0.024537            0.016608
# 4         0.025316        0.054629       0.019874            0.015212
#
#      var_95  max_drawdown  mean_return  ...  bb_width_mean  macd_volatility  \
# 0 -0.017853     -0.236220     0.000743  ...       2.296415         0.176010
# 1 -0.030420     -0.514563     0.000901  ...       3.867892         1.282150
# 2 -0.015898     -0.348232     0.000126  ...       1.752410         5.776191
# 3 -0.041967     -0.392500     0.001923  ...       3.561992         0.576050
# 4 -0.034998     -0.302949     0.001758  ...       3.670978         1.450247
#
#       avg_volume  volume_volatility  amihud_illiquidity  trading_frequency  \
# 0  457918.016194       1.206789e+06        3.464928e-09           1.000000
# 1  233655.667351       4.414206e+06        1.904103e-08           0.985830
# 2   19173.611111       5.648945e+04        1.622817e-09           0.947368
# 3   86221.114865       5.454811e+05        0.000000e+00           0.599190
# 4   10246.268657       7.566827e+04        0.000000e+00           0.406883
#
#    momentum_20d  momentum_60d  trend_strength  current_price
# 0      0.168285      0.284698        0.183930          18.05
# 1     -0.140625     -0.063830       -0.088486          55.00
# 2      0.075823      0.094614        0.068561         376.00
# 3     -0.038405     -0.028358       -0.031970          32.55
# 4     -0.002809      0.123418        0.055134          88.75
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Inspect Features

# %%
print("Feature Summary:")
print(" ")
df_features.info()
# Out:
# Feature Summary:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Stock_code          57 non-null     object
#  1   Sector              57 non-null     object
#  2   Name                57 non-null     object
#  3   volatility_mean     57 non-null     float64
#  4   volatility_max      57 non-null     float64
#  5   volatility_5d       57 non-null     float64
#  6   downside_deviation  57 non-null     float64
#  7   var_95              57 non-null     float64
#  8   max_drawdown        57 non-null     float64
#  9   mean_return         57 non-null     float64
#  10  std_return          57 non-null     float64
#  11  return_skew         57 non-null     float64
#  12  return_kurtosis     57 non-null     float64
#  13  return_consistency  57 non-null     float64
#  14  sharpe_ratio        57 non-null     float64
#  15  rsi_mean            57 non-null     float64
#  16  bb_width_mean       57 non-null     float64
#  17  macd_volatility     57 non-null     float64
#  18  avg_volume          57 non-null     float64
#  19  volume_volatility   57 non-null     float64
#  20  amihud_illiquidity  57 non-null     float64
#  21  trading_frequency   57 non-null     float64
#  22  momentum_20d        57 non-null     float64
#  23  momentum_60d        57 non-null     float64
#  24  trend_strength      57 non-null     float64
#  25  current_price       57 non-null     float64
# dtypes: float64(23), object(3)
# memory usage: 11.7+ KB

# %%
print("\nKey Stats:")
df_features[['volatility_mean', 'sharpe_ratio', 'max_drawdown', 'rsi_mean']].describe().round(4)
# Out:
# Key Stats:
#        volatility_mean  sharpe_ratio  max_drawdown  rsi_mean
# count          57.0000       57.0000       57.0000   57.0000
# mean            0.0259        0.0329       -0.4781   47.0429
# std             0.0099        0.1200        0.1788    7.9726
# min             0.0039       -0.0353       -0.8555    7.3053
# 25%             0.0192        0.0019       -0.6036   47.3420
# 50%             0.0257        0.0137       -0.4833   48.6616
# 75%             0.0348        0.0314       -0.3482   49.6137
# max             0.0460        0.8866       -0.0698   54.6336

# %% [markdown]
# ## Save

# %%
output_path = '../Data/Processed/nse_features.csv'
df_features.to_csv(output_path, index=False)

print(f"   {len(df_features)} stocks × {len(df_features.columns)} features")
# Out:
#    57 stocks × 26 features
